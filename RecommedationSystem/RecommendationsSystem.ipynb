# %%
life_and_programming_sentences = [
    "Life is a journey of constant learning and growth.",
    "Programming is the process of creating instructions for a computer.",
    "Life requires adaptability and resilience.",
    "In programming, debugging is a critical part of the development process.",
    "Life is unpredictable, but programming offers predictable outcomes.",
    "The human brain is incredibly powerful, much like a computer's processing capabilities.",
    "In programming, version control is essential for managing changes.",
    "Life involves making decisions based on our values and priorities.",
    "In programming, algorithms are the backbone of solving complex problems.",
    "Life is full of challenges, but programming provides solutions.",
    "The human heart is a symbol of empathy, much like empathy in programming.",
    "Programming involves problem-solving, just like life challenges.",
    "Life is about connections, and programming is about connections too.",
    "In programming, recursion is a powerful tool for solving complex problems.",
    "Life is a journey of discovery, and programming is a journey of discovery too.",
    "The human spirit is resilient, just like a well-written program.",
    "In programming, recursion is a technique for solving problems with a base case.",
    "Life is a series of events, and programming is a series of instructions.",
    "The human touch is essential in life, and in programming, the right touch can make a difference.",
    "In programming, a well-structured codebase is crucial for maintainability.",
    "Life is a constant cycle of change, and programming reflects this cycle.",
    "The human mind is a creative powerhouse, and programming taps into this creativity.",
    "In programming, a well-documented codebase is essential for collaboration.",
    "Life is a balance of work and rest, and programming requires the same balance.",
    "The human touch in life brings joy, and in programming, a well-written code brings joy too.",
    "In programming, a well-implemented function is a testament to the programmer's skill.",
    "Life is a journey of self-discovery, and programming is a journey of self-discovery too.",
    "The human touch in life brings meaning, and in programming, a well-written code brings meaning too.",
    "In programming, a well-tested codebase is essential for reliability.",
    "Life is a series of experiences, and programming is a series of experiences too.",
    "The human voice is a powerful tool for communication, and in programming, a well-written function is a powerful tool for solving problems.",
    "In programming, a well-designed architecture is crucial for scalability.",
    "Life is a journey of relationships, and programming is a journey of relationships too.",
    "The human eye is a powerful tool for observation, and in programming, a well-written algorithm is a powerful tool for solving problems.",
    "In programming, a well-maintained codebase is essential for longevity.",
    "Life is a journey of exploration, and programming is a journey of exploration too.",
    "The human touch in life brings comfort, and in programming, a well-written code brings comfort too.",
    "In programming, a well-implemented class is a testament to the programmer's skill.",
    "Life is a journey of challenges, and programming is a journey of challenges too.",
    "The human touch in life brings creativity, and in programming, a well-written code brings creativity too.",
    "In programming, a well-optimized codebase is essential for performance.",
    "Life is a journey of growth, and programming is a journey of growth too.",
    "The human touch in life brings empathy, and in programming, a well-written code brings empathy too.",
    "In programming, a well-structured codebase is crucial for maintainability.",
    "Life is a journey of learning, and programming is a journey of learning too.",
    "The human touch in life brings innovation, and in programming, a well-written code brings innovation too.",
    "In programming, a well-documented codebase is essential for collaboration.",
    "Life is a journey of discovery, and programming is a journey of discovery too.",
    "The human touch in life brings joy, and in programming, a well-written code brings joy too.",
    "In programming, a well-tested codebase is essential for reliability.",
    "Life is a journey of self-discovery, and programming is a journey of self-discovery too.",
    "The human touch in life brings meaning, and in programming, a well-written code brings meaning too.",
    "In programming, a well-implemented function is a testament to the programmer's skill.",
    "Life is a journey of exploration, and programming is a journey of exploration too.",
    "The human touch in life brings comfort, and in programming, a well-written code brings comfort too.",
    "In programming, a well-optimized codebase is essential for performance.",
    "Life is a journey of growth, and programming is a journey of growth too.",
    "The human touch in life brings empathy, and in programming, a well-written code brings empathy too.",
    "In programming, a well-structured codebase is crucial for maintainability.",
    "Life is a journey of learning, and programming is a journey of learning too.",
    "The human touch in life brings innovation, and in programming, a well-written code brings innovation too.",
    "In programming, a well-documented codebase is essential for collaboration.",
    "Life is a journey of discovery, and programming is a journey of discovery too.",
    "The human touch in life brings joy, and in programming, a well-written code brings joy too.",
    "In programming, a well-tested codebase is essential for reliability.",
    "Life is a journey of self-discovery, and programming is a journey of self-discovery too.",
    "The human touch in life brings meaning, and in programming, a well-written code brings meaning too.",
    "In programming, a well-implemented function is a testament to the programmer's skill.",
    "Life is a journey of exploration, and programming is a journey of exploration too.",
    "The human touch in life brings comfort, and in programming, a well-written code brings comfort too.",
    "In programming, a well-optimized codebase is essential for performance.",
    "Life is a journey of growth, and programming is a journey of growth too.",
    "The human touch in life brings empathy, and in programming, a well-written code brings empathy too.",
    "In programming, a well-structured codebase is crucial for maintainability.",
    "Life is a journey of learning, and programming is a journey of learning too.",
    "The human touch in life brings innovation, and in programming, a well-written code brings innovation too.",
    "In programming, a well-documented codebase is essential for collaboration.",
    "Life is a journey of discovery, and programming is a journey of discovery too.",
    "The human touch in life brings joy, and in programming, a well-written code brings joy too.",
    "In programming, a well-tested codebase is essential for reliability.",
    "Life is a journey of self-discovery, and programming is a journey of self-discovery too.",
    "The human touch in life brings meaning, and in programming, a well-written code brings meaning too.",
    "In programming, a well-implemented function is a testament to the programmer's skill.",
    "Life is a journey of exploration, and programming is a journey of exploration too.",
    "The human touch in life brings comfort, and in programming, a well-written code brings comfort too.",
    "In programming, a well-optimized codebase is essential for performance.",
    "Life is a journey of growth, and programming is a journey of growth too.",
    "The human touch in life brings empathy, and in programming, a well-written code brings empathy too.",
    "In programming, a well-structured codebase is crucial for maintainability.",
    "Life is a journey of learning, and programming is a journey of learning too.",
    "The human touch in life brings innovation, and in programming, a well-written code brings innovation too.",
    "In programming, a well-documented codebase is essential for collaboration.",
    "Life is a journey of discovery, and programming is a journey of discovery too.",
    "The human touch in life brings joy, and in programming, a well-written code brings joy too.",
    "In programming, a well-tested codebase is essential for reliability.",
    "Life is a journey of self-discovery, and programming is a journey of self-discovery too.",
    "The human touch in life brings meaning, and in programming, a well-written code brings meaning too.",
    "In programming, a well-implemented function is a testament to the programmer's skill.",
    "Life is a journey of exploration, and programming is a journey of exploration too.",
    "The human touch in life brings comfort, and in programming, a well-written code brings comfort too.",
    "In programming, a well-optimized codebase is essential for performance.",
    "Life is a journey of growth, and programming is a journey of growth too.",
    "The human touch in life brings empathy, and in programming, a well-written code brings empathy too.",
    "In programming, a well-structured codebase is crucial for maintainability.",
    "Life is a journey of learning, and programming is a journey of learning too.",
    "The human touch in life brings innovation, and in programming, a well-written code brings innovation too.",
    "In programming, a well-documented codebase is essential for collaboration.",
    "Life is a journey of discovery, and programming is a journey of discovery too.",
    "The human touch in life brings joy, and in programming, a well-written code brings joy too.",
    "In programming, a well-tested codebase is essential for reliability.",
    "Life is a journey of self-discovery, and programming is a journey of self-discovery too.",
    "The human touch in life brings meaning, and in programming, a well-written code brings meaning too.",
    "In programming, a well-implemented function is a testament to the programmer's skill.",
    "Life is a journey of exploration, and programming is a journey of exploration too.",
    "The human touch in life brings comfort, and in programming, a well-written code brings comfort too.",
]

# %%
life_programming = [
    "Life is a journey of constant learning and growth.",
    "Programming is the process of creating instructions for a computer.",
    "Life requires adaptability and resilience.",
    "In programming, debugging is a critical part of the development process.",
    "Life is unpredictable, but programming offers predictable outcomes.",
    "The human brain is incredibly powerful, much like a computer's processing capabilities.",
    "In programming, version control is essential for managing changes.",
    "Life involves making decisions based on our values and priorities.",
    "In programming, algorithms are the backbone of solving complex problems.",
    "Life is full of challenges, but programming provides solutions.",
    "The human heart is a symbol of empathy, much like empathy in programming.",
    "Programming involves problem-solving, just like life challenges.",
    "Life is about connections, and programming is about connections too.",
    "In programming, recursion is a powerful tool for solving complex problems.",
    "Life is a journey of discovery, and programming is a journey of discovery too.",
    "The human spirit is resilient, just like a well-written program.",
    "In programming, recursion is a technique for solving problems with a base case.",
    "Life is a series of events, and programming is a series of instructions.",
    "The human touch is essential in life, and in programming, the right touch can make a difference.",
    "In programming, a well-structured codebase is crucial for maintainability.",
    "Life is a journey of challenges, and programming is a journey of challenges too.",
]

# %%
# run to install required modules for the project
# !pip3 install langchain openai numpy chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 1.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 2.1 MB/s eta 0:00:002.9 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 2.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 2.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 2.8 MB/s eta 0:00:003.4 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 2.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %%
import langchain
import openai
import numpy as np
import chromadb

# %%
# from langchain.embeddings import FakeEmbeddings

# fake_embeddings = FakeEmbeddings(size=1536)

# fake_embeddings_list = []

# for quote in life_and_programming_sentences:
#     fake_embeddings_list.append(fake_embeddings.embed_query(quote))

# %%
# fake_embeddings_list = np.array(fake_embeddings_list).astype("float32")

# %%
# Vector database
from chromadb.utils import embedding_functions

client = chromadb.Client()

embed_func = embedding_functions.OpenAIEmbeddingFunction(
    api_key="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",
    model_name="text-embedding-ada-002"
)

collection = client.create_collection(name="CommentsTester789", embedding_function=embed_func)

collection.add(documents=life_programming,
               ids=[f"id{i}" for i in range(len(life_programming))]
              )

# %%
# Semantic Analysis
query_results = collection.query(query_texts=["I love life"],
                                 n_results=10,
                                )
query_results['documents'][:]
# Out:
# [['Life is a journey of constant learning and growth.',
#   'Life requires adaptability and resilience.',
#   'Life involves making decisions based on our values and priorities.',
#   'Life is full of challenges, but programming provides solutions.',
#   'Life is a journey of challenges, and programming is a journey of challenges too.',
#   'Life is about connections, and programming is about connections too.',
#   'Life is a journey of discovery, and programming is a journey of discovery too.',
#   'Life is a series of events, and programming is a series of instructions.',
#   'The human spirit is resilient, just like a well-written program.',
#   'Life is unpredictable, but programming offers predictable outcomes.']]
